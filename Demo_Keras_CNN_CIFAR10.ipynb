# %% [markdown]
# <a href="https://colab.research.google.com/github/AhirtonLopes/Intro-to-Keras/blob/master/Demo_Keras_CNN_CIFAR10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Demo 3 - Convolutional Neural Networks usando Keras e Ckeras-introIFAR-10
#
# ### 1. Carregando a base CIFAR-10 (imagens rotuladas em macro categorias)
#
# *** Mais informações em https://www.cs.toronto.edu/~kriz/cifar.html ***

# %%
import keras
from keras.datasets import cifar10

#carregando o dataset pré-embaralhado de treinamento bem como os dados de teste
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# ### 2. Visualizando as primeiras 24 imagens do dataset de treinamento

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Redimensionando as imagens e dividindo cada pixel em cada imagem por 255

# %%
# redimensionamento [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Dividindo o dataset em treinamento, teste e validação

# %%
from keras.utils import np_utils

# "one-hot encode" aplicado aos rótulos
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# divindo dataset de treinamento em treinamento, teste e validação
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# impressão da forma do conjunto de treino
print('x_train shape:', x_train.shape)

# impressão do número de imagens nos datasets de treinamento, teste e validação
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# ('x_train shape:', (45000, 32, 32, 3))
# (45000, 'train samples')
# (10000, 'test samples')
# (5000, 'validation samples')

# %% [markdown]
# ### 5. Definindo a arquitetura do modelo (IMPORTANTE!)
#
# * 3 camadas convolucionais de tamanho progressivamente crescente
# * Máximo de camadas de "pooling" (2x2) seguidas por tais 3 camadas convolucionais
# * Uma camada do tipo totalmente conectada de 100 neurônios
# * Últimas camadas do tipo totalmente conectadas de 10 saídas (10 classes de categoria de imagem)
# * "Dropout" de 0,2-0,3

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

# tentem com outras funções de ativação (como visto em nossa Aula 3)
# mais informações em https://keras.io/activations/

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        416
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        8256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         32896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               204900
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 247,478
# Trainable params: 247,478
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compilando o modelo

# %%
# compilando o modelo escolhendo como se dará nossa perda, otimização e métricas (parâmetros do Keras)
# mais informações em https://keras.io/losses/
# mais informações em https://keras.io/optimizers/
# mais informações em https://keras.io/metrics/
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Treinando o modelo

# %%
from keras.callbacks import ModelCheckpoint   

checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=64, epochs=50,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)

# tentem mudar o número de épocas de treinamento e verificar o comportamento de nosso algoritmo
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
#  - 10s - loss: 1.7571 - acc: 0.3635 - val_loss: 1.4694 - val_acc: 0.4674
#
# Epoch 00001: val_loss improved from inf to 1.46940, saving model to model.weights.best.hdf5
# Epoch 2/50
#  - 9s - loss: 1.4148 - acc: 0.4964 - val_loss: 1.2992 - val_acc: 0.5396
#
# Epoch 00002: val_loss improved from 1.46940 to 1.29917, saving model to model.weights.best.hdf5
# Epoch 3/50
#  - 9s - loss: 1.2621 - acc: 0.5512 - val_loss: 1.1731 - val_acc: 0.5890
#
# Epoch 00003: val_loss improved from 1.29917 to 1.17309, saving model to model.weights.best.hdf5
# Epoch 4/50
#  - 9s - loss: 1.1561 - acc: 0.5914 - val_loss: 1.2663 - val_acc: 0.5612
#
# Epoch 00004: val_loss did not improve from 1.17309
# Epoch 5/50
#  - 9s - loss: 1.0815 - acc: 0.6225 - val_loss: 1.0667 - val_acc: 0.6226
#
# Epoch 00005: val_loss improved from 1.17309 to 1.06673, saving model to model.weights.best.hdf5
# Epoch 6/50
#  - 9s - loss: 1.0225 - acc: 0.6405 - val_loss: 1.0234 - val_acc: 0.6554
#
# Epoch 00006: val_loss improved from 1.06673 to 1.02338, saving model to model.weights.best.hdf5
# Epoch 7/50
#  - 9s - loss: 0.9802 - acc: 0.6578 - val_loss: 0.9366 - val_acc: 0.6718
#
# Epoch 00007: val_loss improved from 1.02338 to 0.93657, saving model to model.weights.best.hdf5
# Epoch 8/50
#  - 9s - loss: 0.9476 - acc: 0.6698 - val_loss: 1.0669 - val_acc: 0.6430
#
# Epoch 00008: val_loss did not improve from 0.93657
# Epoch 9/50
#  - 9s - loss: 0.9231 - acc: 0.6803 - val_loss: 0.9627 - val_acc: 0.6800
#
# Epoch 00009: val_loss did not improve from 0.93657
# Epoch 10/50
#  - 9s - loss: 0.9019 - acc: 0.6934 - val_loss: 1.0689 - val_acc: 0.6398
#
# Epoch 00010: val_loss did not improve from 0.93657
# Epoch 11/50
#  - 9s - loss: 0.8823 - acc: 0.6969 - val_loss: 0.8509 - val_acc: 0.7078
#
# Epoch 00011: val_loss improved from 0.93657 to 0.85087, saving model to model.weights.best.hdf5
# Epoch 12/50
#  - 9s - loss: 0.8715 - acc: 0.7024 - val_loss: 0.9217 - val_acc: 0.7020
#
# Epoch 00012: val_loss did not improve from 0.85087
# Epoch 13/50
#  - 9s - loss: 0.8612 - acc: 0.7052 - val_loss: 0.8246 - val_acc: 0.7098
#
# Epoch 00013: val_loss improved from 0.85087 to 0.82456, saving model to model.weights.best.hdf5
# Epoch 14/50
#  - 9s - loss: 0.8573 - acc: 0.7094 - val_loss: 0.8998 - val_acc: 0.7014
#
# Epoch 00014: val_loss did not improve from 0.82456
# Epoch 15/50
#  - 9s - loss: 0.8505 - acc: 0.7140 - val_loss: 0.8986 - val_acc: 0.7154
#
# Epoch 00015: val_loss did not improve from 0.82456
# Epoch 16/50
#  - 9s - loss: 0.8514 - acc: 0.7134 - val_loss: 0.8663 - val_acc: 0.7154
#
# Epoch 00016: val_loss did not improve from 0.82456
# Epoch 17/50
#  - 9s - loss: 0.8429 - acc: 0.7167 - val_loss: 0.8106 - val_acc: 0.7290
#
# Epoch 00017: val_loss improved from 0.82456 to 0.81064, saving model to model.weights.best.hdf5
# Epoch 18/50
#  - 9s - loss: 0.8450 - acc: 0.7156 - val_loss: 0.9162 - val_acc: 0.6972
#
# Epoch 00018: val_loss did not improve from 0.81064
# Epoch 19/50
#  - 9s - loss: 0.8417 - acc: 0.7191 - val_loss: 0.8927 - val_acc: 0.7064
#
# Epoch 00019: val_loss did not improve from 0.81064
# Epoch 20/50
#  - 9s - loss: 0.8398 - acc: 0.7197 - val_loss: 0.9902 - val_acc: 0.6840
#
# Epoch 00020: val_loss did not improve from 0.81064
# Epoch 21/50
#  - 9s - loss: 0.8314 - acc: 0.7228 - val_loss: 0.8516 - val_acc: 0.7134
#
# Epoch 00021: val_loss did not improve from 0.81064
# Epoch 22/50
#  - 9s - loss: 0.8402 - acc: 0.7198 - val_loss: 0.8021 - val_acc: 0.7428
#
# Epoch 00022: val_loss improved from 0.81064 to 0.80206, saving model to model.weights.best.hdf5
# Epoch 23/50
#  - 9s - loss: 0.8408 - acc: 0.7230 - val_loss: 0.8486 - val_acc: 0.7204
#
# Epoch 00023: val_loss did not improve from 0.80206
# Epoch 24/50
#  - 9s - loss: 0.8324 - acc: 0.7235 - val_loss: 0.9693 - val_acc: 0.7096
#
# Epoch 00024: val_loss did not improve from 0.80206
# Epoch 25/50
#  - 9s - loss: 0.8437 - acc: 0.7228 - val_loss: 0.8985 - val_acc: 0.7056
#
# Epoch 00025: val_loss did not improve from 0.80206
# Epoch 26/50
#  - 9s - loss: 0.8496 - acc: 0.7198 - val_loss: 0.8902 - val_acc: 0.7124
#
# Epoch 00026: val_loss did not improve from 0.80206
# Epoch 27/50
#  - 9s - loss: 0.8393 - acc: 0.7225 - val_loss: 1.0230 - val_acc: 0.6832
#
# Epoch 00027: val_loss did not improve from 0.80206
# Epoch 28/50
#  - 9s - loss: 0.8486 - acc: 0.7184 - val_loss: 1.0804 - val_acc: 0.6246
#
# Epoch 00028: val_loss did not improve from 0.80206
# Epoch 29/50
#  - 9s - loss: 0.8528 - acc: 0.7174 - val_loss: 0.8965 - val_acc: 0.7264
#
# Epoch 00029: val_loss did not improve from 0.80206
# Epoch 30/50
#  - 9s - loss: 0.8606 - acc: 0.7172 - val_loss: 0.9981 - val_acc: 0.6964
#
# Epoch 00030: val_loss did not improve from 0.80206
# Epoch 31/50
#  - 9s - loss: 0.8592 - acc: 0.7166 - val_loss: 0.9727 - val_acc: 0.6936
#
# Epoch 00031: val_loss did not improve from 0.80206
# Epoch 32/50
#  - 9s - loss: 0.8702 - acc: 0.7162 - val_loss: 0.9715 - val_acc: 0.7126
#
# Epoch 00032: val_loss did not improve from 0.80206
# Epoch 33/50
#  - 9s - loss: 0.8648 - acc: 0.7136 - val_loss: 0.8605 - val_acc: 0.7288
#
# Epoch 00033: val_loss did not improve from 0.80206
# Epoch 34/50
#  - 9s - loss: 0.8674 - acc: 0.7126 - val_loss: 0.9926 - val_acc: 0.6682
#
# Epoch 00034: val_loss did not improve from 0.80206
# Epoch 35/50
#  - 9s - loss: 0.8783 - acc: 0.7112 - val_loss: 0.8668 - val_acc: 0.7346
#
# Epoch 00035: val_loss did not improve from 0.80206
# Epoch 36/50
#  - 9s - loss: 0.8754 - acc: 0.7114 - val_loss: 1.7063 - val_acc: 0.6262
#
# Epoch 00036: val_loss did not improve from 0.80206
# Epoch 37/50
#  - 9s - loss: 0.8898 - acc: 0.7107 - val_loss: 0.8945 - val_acc: 0.6998
#
# Epoch 00037: val_loss did not improve from 0.80206
# Epoch 38/50
#  - 9s - loss: 0.8886 - acc: 0.7092 - val_loss: 0.9797 - val_acc: 0.6620
#
# Epoch 00038: val_loss did not improve from 0.80206
# Epoch 39/50
#  - 9s - loss: 0.8893 - acc: 0.7090 - val_loss: 1.1642 - val_acc: 0.6598
#
# Epoch 00039: val_loss did not improve from 0.80206
# Epoch 40/50
#  - 9s - loss: 0.9015 - acc: 0.7058 - val_loss: 0.9324 - val_acc: 0.6816
#
# Epoch 00040: val_loss did not improve from 0.80206
# Epoch 41/50
#  - 9s - loss: 0.9023 - acc: 0.7037 - val_loss: 1.0780 - val_acc: 0.7030
#
# Epoch 00041: val_loss did not improve from 0.80206
# Epoch 42/50
#  - 9s - loss: 0.9156 - acc: 0.7020 - val_loss: 0.9010 - val_acc: 0.6990
#
# Epoch 00042: val_loss did not improve from 0.80206
# Epoch 43/50
#  - 9s - loss: 0.9140 - acc: 0.7017 - val_loss: 1.5393 - val_acc: 0.6900
#
# Epoch 00043: val_loss did not improve from 0.80206
# Epoch 44/50
#  - 9s - loss: 0.9203 - acc: 0.7010 - val_loss: 0.8693 - val_acc: 0.7202
#
# Epoch 00044: val_loss did not improve from 0.80206
# Epoch 45/50
#  - 9s - loss: 0.9344 - acc: 0.6977 - val_loss: 1.1366 - val_acc: 0.6504
#
# Epoch 00045: val_loss did not improve from 0.80206
# Epoch 46/50
#  - 9s - loss: 0.9290 - acc: 0.7000 - val_loss: 1.0980 - val_acc: 0.6278
#
# Epoch 00046: val_loss did not improve from 0.80206
# Epoch 47/50
#  - 9s - loss: 0.9377 - acc: 0.6957 - val_loss: 1.6414 - val_acc: 0.6528
#
# Epoch 00047: val_loss did not improve from 0.80206
# Epoch 48/50
#  - 9s - loss: 0.9405 - acc: 0.6961 - val_loss: 1.1376 - val_acc: 0.6028
#
# Epoch 00048: val_loss did not improve from 0.80206
# Epoch 49/50
#  - 9s - loss: 0.9503 - acc: 0.6928 - val_loss: 1.5054 - val_acc: 0.5350
#
# Epoch 00049: val_loss did not improve from 0.80206
# Epoch 50/50
#  - 9s - loss: 0.9498 - acc: 0.6912 - val_loss: 1.0336 - val_acc: 0.7010
#
# Epoch 00050: val_loss did not improve from 0.80206

# %% [markdown]
# ### 8. Carregando o modelo com a melhor precisão de validação

# %%
# carregando os pesos que geraram a melhor precisão de validação
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Cálculo da precisão de classificação no dataset de testes

# %%
# avaliar e imprimir a precisão do teste
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
# ('\n', 'Test accuracy:', 0.7271)

# %% [markdown]
# ### 10. Visualizar algumas predições
#
# As visualizações podem nos dar algumas dicas sobre por que a rede classifica erroneamente alguns objetos.

# %%
# obtendo previsões no conjunto de testes
y_hat = model.predict(x_test)

# definindo rótulos de texto (rótulos disponíveis na fonte original: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot de amostra aleatória de imagens de teste, rótulos preditos e a "ground truth" advinda do dataset CIFAR-10
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
    # amostras corretamente classificadas em verde, incorretamente classificadas em vermelho
